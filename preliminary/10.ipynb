# %%
import pandas as pd
from csv import writer

from lib import lib_soup as sp

# %%
ñ0 = open('data//LN.txt',mode='r')
ñ0 = ñ0.read().split('\n')
ñ0
# Out:
# ['https://www.lanacion.com.ar/espectaculos/teatro/estrenos-de-teatro-las-manos-de-eduviges-al-momento-del-nacer-un-tragedia-alucinada-alrededor-de-un-nid09112022/',
#  'https://www.lanacion.com.ar/espectaculos/teatro/estrenos-de-teatro-el-mecanismo-de-alaska-o-cuando-el-fluir-de-los-pipis-se-diluye-en-su-andar-nid02112022/',
#  'https://www.lanacion.com.ar/espectaculos/danza/obra-del-demonio-una-maquinaria-escenica-atrapante-que-reivindica-a-la-danza-en-su-constante-nid21092022/',
#  'https://www.lanacion.com.ar/espectaculos/teatro/estrenos-de-teatro-metrochenta-esuna-bella-e-intensa-ceremonia-melodramatica-de-dos-gays-del-nid27072022/',
#  'https://www.lanacion.com.ar/espectaculos/teatro/estrenos-de-teatro-pequena-pamela-cuando-los-chispazos-no-siempre-hacen-fuego-nid04052022/',
#  'https://www.lanacion.com.ar/espectaculos/teatro/fiba-glory-wall-una-propuesta-con-un-disparador-inquietante-que-no-llega-a-derribar-paredes-nid04032022/',
# ...

# %%
ñ1 = []
for i in range(0,138):
    s = sp.url_to_soup(ñ0[i])
    ñ1 += [s.find("meta", {"name":"title"})["content"]]

# %%
ñ1
# Out:
# ['Estrenos de teatro: Las manos de Eduviges al momento del nacer, un tragedia alucinada alrededor de un féretro vacío - LA NACION',
#  'Estrenos de teatro: El mecanismo de Alaska, o cuando el fluir de Los Pipis se diluye en su andar - LA NACION',
#  'Obra del demonio: una maquinaria escénica atrapante que reivindica a la danza en su constante evocación de Pina Bausch - LA NACION',
#  'Estrenos de teatro. Metrochenta esuna bella e intensa ceremonia melodramática de dos gays del conurbano - LA NACION',
#  'Estrenos de teatro. Pequeña Pamela, cuando los chispazos no siempre hacen fuego - LA NACION',
#  'FIBA: Glory Wall, una propuesta con un disparador inquietante que no llega a derribar paredes - LA NACION',
#  'FIBA: La Méridienne, una ceremonia a la hora del té que transporta a otros tiempos - LA NACION',
#  'FIBA: Love me, contundente ceremonia íntima, expansiva y catártica de Marina Otero  - LA NACION',
# ...
